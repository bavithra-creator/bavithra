# %% [markdown]
# <a href="https://colab.research.google.com/github/bavithra-creator/bavithra/blob/main/Basic%20details%20of%20student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Store basic details about the student
# Student Profile Creator

# Step 1: Create variables to store student details
student_name = input("Enter the student's name: ")
student_age = int(input("Enter the student's age: "))
favourite_subjects = input("Enter your favourite subjects: ")

# Step 2: Display the student’s information
print("\n--- Student Information ---")
print(f"Name: {student_name}")
print(f"Age: {student_age}")
print(f"Favourite Subjects: {favourite_subjects}")

# Step 3: Ask the student to enter a new favourite subject
new_subject = input("\nEnter a new favourite subject to add: ")

# Step 4: Display the updated list of subjects
print("\n--- Updated Student Information ---")
print(f"Name: {student_name}")
print(f"Age: {student_age}")
print(f"Updated Favourite Subjects: {favourite_subjects}{', '}{new_subject}")
# Out:
# Enter the student's name: Karthik
# Enter the student's age: 29
# Enter your favourite subjects: Geography
#
# --- Student Information ---
# Name: Karthik
# Age: 29
# Favourite Subjects: Geography
#
# Enter a new favourite subject to add: English, Computer science
#
# --- Updated Student Information ---
# Name: Karthik
# Age: 29
# Updated Favourite Subjects: Geography, English, Computer science
